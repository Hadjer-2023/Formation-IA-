# %%
pip install mlflow
# Out:
# ...
#   Using cached mlflow-2.17.2-py3-none-any.whl.metadata (29 kB)
# ...
# Using cached mlflow-2.17.2-py3-none-any.whl (26.7 MB)
# ...

# %%
from sklearn import datasets
from sklearn.model_selection import train_test_split

# %%
from sklearn import datasets

# Appeler la fonction load_diabetes correctement
datasets = "https://raw.githubusercontent.com/RiccardoAncarani/mushrooms-machine-learning/refs/heads/master/mushrooms.csv"
print(datasets)
# Out:
# https://raw.githubusercontent.com/RiccardoAncarani/mushrooms-machine-learning/refs/heads/master/mushrooms.csv

# %%
import pandas as pd

datasets = pd.read_csv(datasets)

# %%
target = 'class' # The class we want to predict
labels = datasets[target]

features = datasets.drop(target, axis=1) # Remove the target class from the dataset

# %%
categorical = features.columns # Since every fearure is categorical we use features.columns
features = pd.concat([features, pd.get_dummies(features[categorical])], axis=1) # Convert every categorical feature with one hot encoding
features.drop(categorical, axis=1, inplace=True) # Drop the original feature, leave only the encoded ones

labels = pd.get_dummies(labels)['p'] # Encode the target class, 1 is deadly 0 is safe

# %%
X_train, X_test, y_train, y_test = train_test_split(features,labels, test_size=0.2, random_state=0)

# %%
X_train.shape
# Out:
# (6499, 117)

# %%
y_train.shape
# Out:
# (6499,)

# %%
X_test.shape
# Out:
# (1625, 117)

# %%
y_test.shape
# Out:
# (1625,)

# %%
X_test
# Out:
#       cap-shape_b  cap-shape_c  cap-shape_f  cap-shape_k  cap-shape_s  \
# 380         False        False        False        False        False
# 3641        False        False         True        False        False
# 273         False        False        False        False        False
# 1029        False        False        False        False        False
# 684         False        False        False        False        False
# ...           ...          ...          ...          ...          ...
# 3535        False        False         True        False        False
# 1643        False        False         True        False        False
# 6494        False        False         True        False        False
# 6            True        False        False        False        False
# 3175        False        False        False        False        False
#
#       cap-shape_x  cap-surface_f  cap-surface_g  cap-surface_s  cap-surface_y  \
# ...

# %%
from sklearn.linear_model import LogisticRegression
clf = LogisticRegression()
clf.fit(X_train, y_train)
# Out:
# LogisticRegression()

# %%
from sklearn.linear_model import LogisticRegression
import mlflow
# Définition d'une expérience (Une expérience peut contenir plusieurs *runs*)
mlflow.set_experiment("Reg_Logistic_Models")
mlflow.sklearn.autolog() # Ici on fait appel à l'API MLflow qui intégre les algos de Scikit-Learn.
                        # C'est grâce à ce code qu'on enregistre toutes les métriques et métadonnées de cette expérience (Module MLflow Tracking)
with mlflow.start_run(run_name = 'reg_logistic_defaut'):
  clf = LogisticRegression()
  clf.fit(X_train, y_train)
# Out:
# 2024/11/06 13:22:52 INFO mlflow.tracking.fluent: Experiment with name 'Reg_Logistic_Models' does not exist. Creating a new experiment.

# %%
# Out:
#   File "<ipython-input-32-a06858abf663>", line 7
#     dt1.fit(X_train, y_train)w.start_run(run_name = 'reg_logistic_max_iter_200'):
#                              ^
# SyntaxError: invalid syntax

# %%
# Création d'une seconde expérience
mlflow.set_experiment("Decision_Tree_Models")
mlflow.sklearn.autolog()
from sklearn.tree import DecisionTreeClassifier
with mlflow.start_run(run_name = 'decision_tree_defaut'):
  dt1 = DecisionTreeClassifier(random_state=seed)
  dt1.fit(X_train, y_train)
# Out:
# 2024/11/06 13:24:51 INFO mlflow.tracking.fluent: Experiment with name 'Decision_Tree_Models' does not exist. Creating a new experiment.

# %%
with mlflow.start_run(run_name = 'decision_tree_max_depth3'):
  dt2 = DecisionTreeClassifier(random_state=seed, max_depth=3)
  dt2.fit(X_train, y_train)

# %%
import numpy as np
new_data = np.array([[6.5, 3.2, 5.5, 1.9]])
new_data
# Out:
# array([[6.5, 3.2, 5.5, 1.9]])

# %%
new_data.shape
# Out:
# (1, 4)

# %%
pip install pyngrok

# %%
from pyngrok import ngrok

# %%
import mlflow
mlflow.set_tracking_uri("https://9a79-34-73-116-252.ngrok-free.app/")

# %%
mlflow.set_experiment("Reg_Logistic_Models_H")
mlflow.sklearn.autolog() # Ici on fait appel à l'API MLflow qui intégre les algos de Scikit-Learn.
                        # C'est grâce à ce code qu'on enregistre toutes les métriques et métadonnées de cette expérience (Module MLflow Tracking)
with mlflow.start_run(run_name = 'reg_logistic_defaut_H'):
  clf = LogisticRegression()
clf.fit(X_train, y_train)
# Out:
# 2024/11/06 13:57:06 INFO mlflow.tracking.fluent: Experiment with name 'Reg_Logistic_Models_H' does not exist. Creating a new experiment.
# 2024/11/06 13:57:07 INFO mlflow.tracking._tracking_service.client: 🏃 View run reg_logistic_defaut_H at: https://9a79-34-73-116-252.ngrok-free.app/#/experiments/565840413350973706/runs/eeb0c614e240425a833a170dbf47fe49.
# 2024/11/06 13:57:07 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: https://9a79-34-73-116-252.ngrok-free.app/#/experiments/565840413350973706.
# 2024/11/06 13:57:07 INFO mlflow.utils.autologging_utils: Created MLflow autologging run with ID '4109d8f90a94469b81ea6d71ce5ed8be', which will track hyperparameters, performance metrics, model artifacts, and lineage information for the current sklearn workflow
# ...

# %%
# !mlflow ui
# Out:
# [2024-11-06 13:57:40 +0000] [14821] [INFO] Starting gunicorn 23.0.0
# [2024-11-06 13:57:40 +0000] [14821] [INFO] Listening at: http://127.0.0.1:5000 (14821)
# [2024-11-06 13:57:40 +0000] [14821] [INFO] Using worker: sync
# [2024-11-06 13:57:40 +0000] [14822] [INFO] Booting worker with pid: 14822
# [2024-11-06 13:57:40 +0000] [14823] [INFO] Booting worker with pid: 14823
# [2024-11-06 13:57:40 +0000] [14824] [INFO] Booting worker with pid: 14824
# [2024-11-06 13:57:40 +0000] [14825] [INFO] Booting worker with pid: 14825
# [2024-11-06 13:58:02 +0000] [14821] [INFO] Handling signal: int
# [2024-11-06 13:58:03 +0000] [14823] [INFO] Worker exiting (pid: 14823)
# [2024-11-06 13:58:03 +0000] [14825] [INFO] Worker exiting (pid: 14825)
# [2024-11-06 13:58:03 +0000] [14822] [INFO] Worker exiting (pid: 14822)
# [2024-11-06 13:58:03 +0000] [14824] [INFO] Worker exiting (pid: 14824)
#
# Aborted!
# [2024-11-06 13:58:04 +0000] [14821] [INFO] Shutting down: Master
